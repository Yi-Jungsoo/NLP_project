# %% [markdown]
# <a href="https://colab.research.google.com/github/natsuasa/NLP_project/blob/master/nlp_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from konlpy.tag import Okt

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objs as go
from konlpy.tag import Kkma
from konlpy.utils import pprint
from nltk.tokenize import sent_tokenize

# %%
import urllib.request
import pandas as pd
from konlpy.tag import Mecab
from nltk import FreqDist
import numpy as np
import matplotlib.pyplot as plt

# %%
report1=pd.read_csv('/content/Naver_News_인공지능.csv')
report1

# %%
report1[''] = report1['content'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
report1
# Out:
# <ipython-input-132-928b58832c6c>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                                 title  \
# 0   [국제인공지능&amp;윤리협회-대진대학교, AI 인재양성 및 사업협력을 위한 공동 ...
# 1            [도쉼, 인공지능 작품 전시회 ‘DOSHIM AI ART’ 26일 개최]
# 2                       [서울대 공대, 현대중공업그룹과 인공지능 포럼 개최]
# 3                    [현대건설, 인공지능 기반 CCTV 영상분석 시스템 개발]
# 4                         [포항시, ‘산업안전 인공지능연구센터’ 문 열어]
# 5                            [[투데이 窓]인공지능과 문화콘텐츠의 미래]
# 6               [대전시, 물산업에 인공지능 접목해 ‘물순환 선도도시’로 거듭난다]
# 7                           [해군 7기동전단에 인공지능 교육장 문 열어]
# 8                ['목소리로 안전 예측' 아이티공간, 인공지능 경진대회 '대상']
# 9                 [로봇·인공지능으로 토마토 수확시기 예측한다…정확도 92.1%]
# 10                  [현대건설, 인공지능 영상 분석 기술로 안전·품질 관리한다]
# 11                  [현대건설, 인공지능 영상 분석 기술로 안전·품질 관리한다]
# 12                        [포항시, ‘산업안전 인공지능연구센터’ 문 열어]
# 13                   [필라웨어, 고려대 언어정보연구소와 '인공지능' 업무협약]
# ...

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
kkma=Kkma()

# %%
df=pd.DataFrame()
for i in range(len(report1)):
  a=report1['content'][i]
  b=kkma.nouns(a)
  df=df.append(b, ignore_index=True)
df
# Out:
#          0
# 0       탄소
# 1     탄소중립
# 2       중립
# 3      바이오
# 4       헬스
# ...    ...
# 5678  중이다라
# 5679    다라
# 5680    기간
# 5681    불편
# 5682   최소화
#
# [5683 rows x 1 columns]

# %%
df.rename(columns = {df.columns[0] : "word"}, inplace = True)

# %%
df.rename(columns = {df.columns[0] : "word"}, inplace = True)
final=pd.value_counts(df['word'].values, sort=True)
finaldf=pd.DataFrame(final)
finaldf
# Out:
#        0
# 지능    32
# 인공    31
# 인공지능  31
# 일     30
# 수     29
# ...   ..
# 공과     1
# 필라웨어   1
# 필      1
# 공과대학   1
# 최소화    1
#
# [2864 rows x 1 columns]

# %%
# list=[]
# for i in range(len(report1)):
#   list=report1['content'][i]
# from nltk.tokenize import sent_tokenize
# tokenized_text = sent_tokenize(list)
# print(tokenized_text)
# Out:
# ['연말까지 시민 밀집 지역사고 다발지역 등 중심자전거도로 보행자 보호 위해 안전등도 시범 설치서울 서초구 반포 한강공원에서 시민들이 자전거를 타고 있다 뉴스   조태형 기자서울뉴스 박우영 기자  서울시 한강사업본부는 안전을 최우선해 한강공원 자전거도로 개선 공사를 실시한다고 일 밝혔다이번 공사는 단계별로 추진된다 올 연말까지는 시민 밀집 지역사고 다발지역 등 개선 시 사고 예방 효과가 높은 지역을 중심으로 스마트 시스템을 구축하고 자전거도로 구조 개선을 병행할 계획이다시는 먼저 각 한강공원에 인공지능 와 속도 표출기를 설치 중이다 지난해 설치를 마친 반포한강공원개소을 제외한 나머지 개 한강공원에 오는 연말까지 설치를 완료할 계획이다인공지능  및 속도 표출기는 자전거도로 이용자가 시속  이상 주행시 전광판에 속도를 표출하고 경고음을 발생시켜 감속을 유도한다 또한 인공지능 속도 분석이 가능해 향후 다양한 안전장치 마련에 활용 가능하다또 자전거도로 횡단보도를 건너는 보행자를 보호하기 위한 안전등인 괄호등과 쉼표등도 개소에 시범 설치된다괄호등은 보행자를 위해 횡단보도 양쪽 끝에 괄호 모양으로 설치하는 조명이다 쉼표등의 경우 자전거도로 이용자를 위해 횡단보도에서 내지  떨어진 곳에 설치하는 쉼표 모양의 조명이다 자전거와 보행자가 접근시 각 등에 자동으로 불이 켜지고 신호음이 울려 서로를 인식할 수 있게 해준다광나루 여의도한강공원 개소에는 복합 기능을 가진 스마트 시스템이 시범 구축될 예정이다 스마트 시스템은 문자 정보 송출   바닥조명 속도 표출기 인공지능  등을 통해 과속 시 안내는 물론 돌발 상황 감지시 통합관리센터에 정보가 전송돼 즉시 안내방송이 이루어질 수 있다시는 자전거도로 구조 개선사업도 지속 병행한다 보행자가 많은 광나루 자전거공원 주변 약  구간에는 권장 속도가 시속 인 보행자 보호구역을 시범 운영하고 사고가 자주 발생하는 강서 행주대교 하부 교차로도 구조 개선이 이뤄진다 난지 익스트림장 주변에는 어린이 가족 연인 누구나 자유롭게 자전거를 즐길 수 
# ...

# %%
fianal=pd.value_counts(df['word'].values, sort=True)
finaldf=pd.DataFrame(final)
finaldf=finaldf.reset_index().rename(columns={"index":"word"})
finaldf.rename(columns = {finaldf.columns[1] : "count"}, inplace = True)
finaldf
# Out:
#       word  count
# 0       지능     32
# 1       인공     31
# 2     인공지능     31
# 3        일     30
# 4        수     29
# ...    ...    ...
# 2859    공과      1
# 2860  필라웨어      1
# 2861     필      1
# 2862  공과대학      1
# 2863   최소화      1
#
# [2864 rows x 2 columns]

# %%
kkk=finaldf[finaldf['count']<10].index
finaldf=finaldf.drop(kkk)
finaldf
# Out:
#     word  count
# 0     지능     32
# 1     인공     31
# 2   인공지능     31
# 3      일     30
# 4      수     29
# 5     기술     26
# 6      등     25
# 7     활용     20
# 8     다양     20
# 9     사진     18
# 10    제공     18
# 11    분야     18
# 12   데이터     17
# 13    개발     17
# 14    가능     17
# 15    기업     16
# 16    정보     16
# 17    기반     15
# 18    기자     14
# 19   시스템     14
# 20   스마트     14
# 21    계획     14
# 22    연구     13
# 23    전문     13
# 24     시     13
# 25    관리     13
# 26    국내     13
# 27    학습     13
# 28    서울     12
# 29    구축     12
# 30     월     12
# 31    대표     12
# 32     년     12
# 33    산업     12
# 34   서비스     12
# 35    이번     12
# 36    진행     12
# 37   실시간     11
# 38     뉴     11
# 39    발전     11
# 40    시대     11
# 41    개최     11
# 42    분석     11
# 43   전문가     10
# 44    필요     10
# 45    인식     10
# 46    사업     10
# 47    현장     10
# 48    확보     10
# 49    예측     10

# %%
# from nltk.tokenize import sent_tokenize
# tokenized_text = sent_tokenize(text)
# print(tokenized_text)

# %%
# result =[]
# result = [okt.nouns(i) for i in line] #명사만 추출
# final_result= [r for i in result for r in i]
# print(final_result)

# %%
fig = px.bar(finaldf,
             x='word',
             y='count',

)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig1 = px.density_heatmap(finaldf,
                          x="word",
                          y="count "
)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
